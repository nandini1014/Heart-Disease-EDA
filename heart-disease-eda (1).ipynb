# %%
import seaborn as sns
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/heart-failure-prediction/heart.csv

# %%
df = pd.read_csv("/kaggle/input/heart-failure-prediction/heart.csv")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# # Distribution plot for numeric columns

# %%
sns.displot(df['Age'] , kde = True)

# %%
for i in df.columns:
    print(i , df[i].nunique())
# Out:
# Age 50
# Sex 2
# ChestPainType 4
# RestingBP 67
# Cholesterol 222
# FastingBS 2
# RestingECG 3
# MaxHR 119
# ExerciseAngina 2
# Oldpeak 53
# ST_Slope 3
# HeartDisease 2

# %%
sns.distplot(df['Age'] , hist = True, kde = True ,rug = True ,bins = 5)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['RestingBP'] , color = 'red' , kde = True)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df['MaxHR'] , color = 'orange' , kde = True)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='MaxHR', ylabel='Density'>

# %%
sns.distplot(df['Cholesterol'] , kde = True)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='Cholesterol', ylabel='Density'>

# %% [markdown]
# ## Pie charts for Categorical Columns

# %%
df.groupby('Sex').size().plot(kind = 'pie' , autopct = '%.0f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.groupby('ChestPainType').size().plot(kind = 'pie',autopct = '%.1f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.groupby('RestingECG').size().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.groupby('ST_Slope').size().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# # ViolinPlot for analyzing more than one column at a time

# %%
sns.violinplot(x = df['HeartDisease'] , y = df['Sex'])
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(x = df['HeartDisease'], y = df['Age'],palette = 'Blues')
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='Age'>

# %% [markdown]
# # Correlation heatmap ( analyzing if one column increases then the other will either increase or decrease )

# %%
df.corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Pair plot

# %%
sns.pairplot(df)

# %% [markdown]
# # JointPlot

# %%
sns.jointplot(x = 'Age',y = 'MaxHR',data = df,kind = 'reg')

# %%
sns.jointplot( x = 'Age',y='Age',data = df,kind = 'reg')

# %%
sns.jointplot( x ='MaxHR',y = 'Cholesterol',data = df,kind = 'reg')
